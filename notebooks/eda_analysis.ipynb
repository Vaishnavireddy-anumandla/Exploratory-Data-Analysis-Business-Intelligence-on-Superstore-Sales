# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.listdir()
# Out:
# ['eda_analysis.ipynb']

# %%
df = pd.read_csv("../data/sales_data.csv")
df.head()
# Out:
#    order_id  order_date customer_name       city     category product_name  \
# 0         1  2024-01-05         Rahul  Hyderabad  Electronics       Laptop
# 1         2  2024-01-06         Priya    Chennai    Furniture        Chair
# 2         3  2024-01-07          Amit  Bangalore  Electronics       Mobile
# 3         4  2024-01-08         Sneha     Mumbai     Clothing      T-Shirt
# 4         5  2024-01-09         Karan      Delhi  Electronics       Tablet
#
#    sales  quantity  profit
# 0  55000         1    5000
# 1   3000         2     500
# 2  20000         1    2000
# 3    800         3     200
# 4  15000         1    1500

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       20 non-null     int64
#  1   order_date     20 non-null     object
#  2   customer_name  20 non-null     object
#  3   city           20 non-null     object
#  4   category       20 non-null     object
#  5   product_name   20 non-null     object
#  6   sales          20 non-null     int64
#  7   quantity       20 non-null     int64
#  8   profit         20 non-null     int64
# dtypes: int64(4), object(5)
# memory usage: 1.5+ KB
#        order_id        sales   quantity       profit
# count  20.00000     20.00000  20.000000    20.000000
# mean   10.50000  16180.00000   1.450000  1872.500000
# std     5.91608  17093.10726   0.604805  1724.168373
# min     1.00000    800.00000   1.000000   200.000000
# 25%     5.75000   2075.00000   1.000000   437.500000
# 50%    10.50000  10750.00000   1.000000  1200.000000
# 75%    15.25000  25250.00000   2.000000  3525.000000
# max    20.00000  56000.00000   3.000000  5200.000000

# %%
df.isnull().sum()
# Out:
# order_id         0
# order_date       0
# customer_name    0
# city             0
# category         0
# product_name     0
# sales            0
# quantity         0
# profit           0
# dtype: int64

# %%
plt.hist(df['sales'], bins=10)
plt.title("Sales Distribution")
plt.show()

# %%
df['category'].value_counts().plot(kind='bar')
plt.title("Products by Category")
plt.show()

# %%
sns.scatterplot(x='sales', y='profit', data=df)
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
